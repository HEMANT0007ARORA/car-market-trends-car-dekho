# %% [markdown]
# # Car Market Trends Analysis — Car Dekho
#
# Exploratory data analysis using Pandas, NumPy and Matplotlib.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../data/car_data.csv')
data.head()

# %%
# Statistical features
data.describe()

# %%
# Variable details
data.info()

# %%
# Missing values
data.isnull().sum()

# %%
# Categorical frequency analysis
print(data.Car_Name.value_counts())
print(data.Fuel_Type.value_counts())

# %%
# Derived depreciation metrics
data['Depreciation'] = data['Present_Price'] - data['Selling_Price']
data['Retention'] = data['Selling_Price'] / data['Present_Price']
data[['Car_Name','Year','Selling_Price','Present_Price','Depreciation','Retention']].head()
